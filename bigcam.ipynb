# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("data_scaled.csv") 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 18 columns):
# OBJECTID      353 non-null int64
# BASE_YEAR     353 non-null int64
# ADM_DR_CD     353 non-null int64
# FID_1         353 non-null int64
# ADM_DR_C_1    353 non-null int64
# SIDO_NM       353 non-null object
# SIGUNGU_CD    353 non-null int64
# SIGUNGU_NM    353 non-null object
# DONG_NM       353 non-null object
# new_name      353 non-null object
# old           353 non-null float64
# child         353 non-null float64
# elem          353 non-null float64
# accident      353 non-null float64
# policefire    353 non-null float64
# cctv          353 non-null float64
# pop           353 non-null float64
# speed         353 non-null float64
# dtypes: float64(8), int64(6), object(4)
# memory usage: 49.7+ KB

# %%
data.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name       old     child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  0.082569  0.075472   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  0.588379  0.075472   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  0.204587  0.075472   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  0.113761  0.000000   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  0.381651  0.037736   0.4  0.151515    0.418454
#
#        cctv       pop     speed
# ...

# %%
from scipy.stats.mstats import gmean

data['Gmean'] = gmean(data.iloc[:,10:],axis=1)

# %%
data.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name       old     child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  0.082569  0.075472   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  0.588379  0.075472   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  0.204587  0.075472   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  0.113761  0.000000   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  0.381651  0.037736   0.4  0.151515    0.418454
#
#        cctv       pop     speed     Gmean
# ...

# %%
data.sort_values(["Gmean"], ascending=[False])
# Out:
#      OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 23        748       2015    1115066    234     1115066   서울특별시       11150
# 64       1828       2015    1123064    378     1123064   서울특별시       11230
# 311      2043       2015    1117051    274     1117051   서울특별시       11170
# 170      1397       2015    1122066    342     1122066   서울특별시       11220
# 295      2026       2015    1119054    300     1119054   서울특별시       11190
# 258      1460       2015    1120073    310     1120073   서울특별시       11200
# 177      1405       2015    1122054    350     1122054   서울특별시       11220
# 175      1403       2015    1122053    348     1122053   서울특별시       11220
# 171      1398       2015    1122063    343     1122063   서울특별시       11220
# 90       1857       2015    1112052    188     1112052   서울특별시       11120
# 95        817       2015    1111079    158     1111079   서울특별시       11110
# ...

# %%
data.to_csv("data_gmean.csv", index=False)

# %%
df = pd.read_csv("risk_index.csv", engine='python')

# %%
df.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name       old     child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  0.083130  0.092593   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  0.588631  0.092593   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  0.205073  0.092593   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  0.114303  0.018519   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  0.382029  0.055556   0.4  0.151515    0.418454
#
#        cctv       pop     speed  risk_index  risk_index_1
# ...

# %%
crime = pd.read_csv("crime.csv", engine='python')

# %%
crime.head()
# Out:
#   SIGUNGU_NM  crime  살인  강도  강간강제추행     절도     폭력
# 0        종로구  4,057   7  10     253  1,644  2,143
# 1         중구  4,184   1   9     267  1,846  2,061
# 2        용산구  4,060   1   5     327  1,346  2,381
# 3        성동구  2,767   1   3     132  1,072  1,559
# 4        광진구  4,646   6  13     261  2,220  2,146

# %%
risk = pd.merge(df, crime[['SIGUNGU_NM','crime']], on = 'SIGUNGU_NM')

# %%
risk.shape
# Out:
# (424, 21)

# %%
risk.to_csv("risk.csv", index=False)

# %%
risk.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name  ...       child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  ...    0.092593   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  ...    0.092593   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  ...    0.092593   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  ...    0.018519   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  ...    0.055556   0.4  0.151515    0.418454
#
#        cctv       pop     speed  risk_index  risk_index_1  crime
# ...

# %%
real_risk = pd.read_csv("risk.csv")

# %%
real_risk.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name  ...       child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  ...    0.092593   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  ...    0.092593   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  ...    0.092593   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  ...    0.018519   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  ...    0.055556   0.4  0.151515    0.418454
#
#        cctv       pop     speed  risk_index  risk_index_1  crime
# ...

# %%
real_risk = real_risk.drop(['risk_index','risk_index_1'], axis = 1)

# %%
real_risk
# Out:
#      OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0        2085       2015    1101060     11     1101060   서울특별시       11010
# 1        2086       2015    1101073     12     1101073   서울특별시       11010
# 2        2087       2015    1101072     13     1101072   서울특별시       11010
# 3        2088       2015    1101054     14     1101054   서울특별시       11010
# 4        2089       2015    1101055     15     1101055   서울특별시       11010
# 5        2090       2015    1101056     16     1101056   서울특별시       11010
# 6        2074       2015    1101067      0     1101067   서울특별시       11010
# 7        2075       2015    1101063      1     1101063   서울특별시       11010
# 8        2076       2015    1101058      2     1101058   서울특별시       11010
# 9        2077       2015    1101071      3     1101071   서울특별시       11010
# 10       2078       2015    1101053      4     1101053   서울특별시       11010
# ...

# %%
real_risk.to_csv("real_risk.csv", index=False)

# %%
ww = pd.read_csv("weightsum.csv")

# %%
ww.head()
# Out:
#    OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 0      2085       2015    1101060     11     1101060   서울특별시       11010
# 1      2086       2015    1101073     12     1101073   서울특별시       11010
# 2      2087       2015    1101072     13     1101072   서울특별시       11010
# 3      2088       2015    1101054     14     1101054   서울특별시       11010
# 4      2089       2015    1101055     15     1101055   서울특별시       11010
#
#   SIGUNGU_NM DONG_NM new_name       old     child  elem  accident  policefire  \
# 0        종로구     가회동      가회동  0.083130  0.092593   0.2  0.030303    0.241827
# 1        종로구     혜화동      혜화동  0.588631  0.092593   0.2  0.121212    0.000000
# 2        종로구   청운효자동    청운효자동  0.205073  0.092593   0.2  0.121212    0.418454
# 3        종로구     삼청동      삼청동  0.114303  0.018519   0.0  0.030303    0.241827
# 4        종로구     부암동      부암동  0.382029  0.055556   0.4  0.151515    0.418454
#
#        cctv       pop     speed     crime  risk_index
# ...

# %%
ww.sort_values('pop', ascending=False)
# Out:
#      OBJECTID  BASE_YEAR  ADM_DR_CD  FID_1  ADM_DR_C_1 SIDO_NM  SIGUNGU_CD  \
# 267      1945       2015    1102055     26     1102055   서울특별시       11020
# 16       2084       2015    1101061     10     1101061   서울특별시       11010
# 207      1405       2015    1122054    350     1122054   서울특별시       11220
# 261      1939       2015    1102054     20     1102054   서울특별시       11020
# 275      1435       2015    1113075    194     1113075   서울특별시       11130
# 76       1828       2015    1123064    378     1123064   서울특별시       11230
# 266      1944       2015    1102052     25     1102052   서울특별시       11020
# 81       1833       2015    1114066    210     1114066   서울특별시       11140
# 71       1823       2015    1123051    373     1123051   서울특별시       11230
# 355      2025       2015    1119074    299     1119074   서울특별시       11190
# 290      1975       2015    1125066    409     1125066   서울특별시       11250
# ...
